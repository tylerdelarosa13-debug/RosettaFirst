# %% [markdown]
# <a href="https://colab.research.google.com/github/tylerdelarosa13-debug/RosettaFirst/blob/main/Listas_indexacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Gʻlista_vacia = []
type(lista_vacia) #Me indica que tipo de variable estoy usando
# Out:
# list

# %%
lista_num = [1,24.5,14,29]
print(lista_num)
# Out:
# [1, 24.5, 14, 29]

# %%
lista_combinados = ["Medellín", "Camilo", 34, True]
print(lista_combinados)
# Out:
# ['Medellín', 'Camilo', 34, True]

# %%
a = []
print(dir(a)) # El dir es para mirar los metodos que hay para el tipo de variable, ya sea entero, lista, etc.
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
vacio = []
vacio.append(4.5) # .append sirve para agregar valores a una lista. Sirve mas que todo para ciclos.
vacio.append(13)
print(vacio)
# Out:
# [4.5, 13]
# 2

# %%
sum(vacio) #Suma de los numeros en la lista
# Out:
# 17.5

# %%
len(vacio) #Cantidad de datos que hay en esa lista
# Out:
# 2

# %%
min(vacio) #El numero minimo de la lista y con max seria al reves, es decir, max(vacio)
# Out:
# 4.5

# %%
# dato1: ciudad   dato2: Nombre    dato 3: Edad   dato4: Trabaja?    dato5: Estudia?
datos_alex = ["medellin", "Alex", 18, True, "Si"] #Indexar es una lista que nos permite obtener los datos que deseamos de esta en un momento determinado
datos_mirella = ["bogota", "mirella", 51, False, "No"]

# %%
alex_trabaj = datos_alex[3]
ana_estudia = datos_mirella[4]
datos_alex[-1]
# Out:
# 'Si'

# %%
datos_alex[0:1+1]
# Out:
# ['medellin', 'Alex']

# %%
datos_mirella[-3:]
# Out:
# [51, False, 'No']

# %%
datos_alex[1:]
# Out:
# ['Alex', 18, True, 'Si']

# %%
nombres = [datos_alex[1], datos_mirella[1]] #Por ejemplo esto es indexación y en este caso me genera una lista de listas
print(nombres)
# Out:
# ['Alex', 'mirella']

# %%
datos = [datos_alex[1:4], datos_mirella[1:4]] #En este caso me genera una lista de listas
print(nombres)
# Out:
# [['Alex', 18, True], ['mirella', 51, False]]

# %%
datos[0][2] #Como es una lista de listas entonces primero la lista que se creo que fue datos que esta en la poicision 2 y por ultimo la lista de afuera que es la posicion 0
print(datos[1][2])
# Out:
# False

# %%
datos.append(["Camila", 20, True])
print(datos)
# Out:
# [['Alex', 18, True], ['mirella', 51, False], ['Camila', 20, True]]

# %%
datos_alex = ["medellin", "Alex", 18, True, "Si"] #Para hacer una actualización
datos_alex[3] = False ; print(datos_alex)
# Out:
# ['medellin', 'Alex', 18, False, 'Si']

# %%
datos_carlos = ["Santa marta", "Carlos", 26, False, "si"] #Para actualizar
datos[-2] = datos_carlos ; print(datos)
# Out:
# [['Alex', 18, True], ['Santa marta', 'Carlos', 26, False, 'si'], ['Camila', 20, True]]

# %%
datos[1][-2] = 27 ; print(datos)
# Out:
# [['Alex', 18, True], ['Santa marta', 'Carlos', 'santa marta', 27, 'si'], ['Camila', 20, True]]

# %% [markdown]
# **EJERCICIOS**

# %%
gata = [2,1,8,7,9,3,5]

# %%
gata.pop(5)
# Out:
# 3

# %%
mica.append(0)
mica.append(1)
mica.append(3)
print(mica)
# Out:
# [[0, 1, 3], [2, 1, 8, 7, 9, 5], 0, 1, 3]

# %%
mica.sort()
print(mica)
# Out:
# [[0, 1, 3], [2, 1, 8, 7, 9, 5]]

# %%
max(mica)
# Out:
# [2, 1, 8, 7, 9, 5]

# %%
min(mica)
# Out:
# [0, 1, 3]

# %%
sum(gata)
# Out:
# 0

# %%
len(mica)
# Out:
# 2

# %%
promedio = sum(gata)/len(gata)
print(promedio)
# Out:
# 5.333333333333333

# %%
gata.clear()
print(gata)
# Out:
# []
